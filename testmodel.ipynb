# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\ryan1\anaconda3\lib\site-packages (2.2.0)
# Requirement already satisfied: protobuf>=3.8.0 in c:\users\ryan1\anaconda3\lib\site-packages (from tensorflow) (3.12.2)
# Requirement already satisfied: tensorboard<2.3.0,>=2.2.0 in c:\users\ryan1\anaconda3\lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in c:\users\ryan1\anaconda3\lib\site-packages (from tensorflow) (1.4.1)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\ryan1\anaconda3\lib\site-packages (from tensorflow) (1.29.0)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\ryan1\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\ryan1\anaconda3\lib\site-packages (from tensorflow) (1.11.2)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\users\ryan1\anaconda3\lib\site-packages (from tensorflow) (1.18.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ryan1\anaconda3\lib\site-packages (from tensorflow) (3.2.1)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in c:\users\ryan1\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in c:\users\ryan1\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\ryan1\anaconda3\lib\site-packages (from tensorflow) (0.9.0)
# Requirement already satisfied: google-pasta>=0.1.8 in c:\users\ryan1\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: gast==0.3.3 in c:\users\ryan1\anaconda3\lib\site-packages (from tensorflow) (0.3.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ryan1\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ryan1\anaconda3\lib\site-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in c:\users\ryan1\anaconda3\lib\site-packages (from tensorflow) (0.34.2)
# Requirement already satisfied: tensorflow-estimator<2.3.0,>=2.2.0 in c:\users\ryan1\anaconda3\lib\site-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: setuptools in c:\users\ryan1\anaconda3\lib\site-packages (from protobuf>=3.8.0->tensorflow) (45.2.0.post20200210)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\ryan1\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (1.0.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ryan1\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (2.22.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ryan1\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (3.2.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\ryan1\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (1.17.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\ryan1\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (0.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\ryan1\anaconda3\lib\site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow) (1.6.0.post3)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\ryan1\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\ryan1\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\ryan1\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ryan1\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow) (2019.11.28)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\ryan1\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow) (1.5.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in c:\users\ryan1\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ryan1\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\ryan1\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (4.1.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ryan1\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\ryan1\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow) (2.2.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\ryan1\anaconda3\lib\site-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ryan1\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow) (3.1.0)

# %%
import tensorflow.compat.v1 as tf

tf.disable_v2_behavior()

import numpy as np

import matplotlib.pyplot as plt

#from tensorflow.examples.tutorials.mnist import input_data

from IPython.display import HTML






#이미 그래프가 있을 경우 중복이 될 수 있기 때문에, 기존 그래프를 모두 리셋한다.

tf.reset_default_graph() 


num_filters1 = 32



x = tf.placeholder(tf.float32, [None, 784])

x_image = tf.reshape(x, [-1,28,28,1])



#  layer 1

W_conv1 = tf.Variable(tf.truncated_normal([3,3,1,num_filters1],

                                          stddev=0.01))

h_conv1 = tf.nn.conv2d(x_image, W_conv1,

                       strides=[1,1,1,1], padding='SAME')



b_conv1 = tf.Variable(tf.constant(0.1, shape=[num_filters1]))

h_conv1_cutoff = tf.nn.relu(h_conv1 + b_conv1)



h_pool1 =tf.nn.max_pool(h_conv1_cutoff, ksize=[1,2,2,1],

                        strides=[1,2,2,1], padding='SAME')



num_filters2 = 64



# layer 2

W_conv2 = tf.Variable(

            tf.truncated_normal([3,3,num_filters1,num_filters2],

                                stddev=0.01))

h_conv2 = tf.nn.conv2d(h_pool1, W_conv2,

                       strides=[1,1,1,1], padding='SAME')



b_conv2 = tf.Variable(tf.constant(0.1, shape=[num_filters2]))

h_conv2_cutoff = tf.nn.relu(h_conv2 + b_conv2)



h_pool2 =tf.nn.max_pool(h_conv2_cutoff, ksize=[1,2,2,1],

                        strides=[1,2,2,1], padding='SAME')



# fully connected layer

h_pool2_flat = tf.reshape(h_pool2, [-1, 7*7*num_filters2])



num_units1 = 7*7*num_filters2

num_units2 = 1024



w2 = tf.Variable(tf.truncated_normal([num_units1, num_units2]))

b2 = tf.Variable(tf.constant(0.1, shape=[num_units2]))

hidden2 = tf.nn.relu(tf.matmul(h_pool2_flat, w2) + b2)



keep_prob = tf.placeholder(tf.float32)

hidden2_drop = tf.nn.dropout(hidden2, keep_prob)



w0 = tf.Variable(tf.zeros([num_units2, 10]))

b0 = tf.Variable(tf.zeros([10]))

k = tf.matmul(hidden2_drop, w0) + b0

p = tf.nn.softmax(k)



# prepare session

sess = tf.InteractiveSession()

sess.run(tf.global_variables_initializer())

saver = tf.train.Saver()

saver.restore(sess, '/Users/ryan1/picture doodle/cnn_session1')



print('reload has been done')
# Out:
# INFO:tensorflow:Restoring parameters from /Users/ryan1/picture doodle/cnn_session1
# reload has been done

# %%
print("물고기가 잡혔습니다")
# Out:
# 물고기가 잡혔습니다

# %%
input_form = """

<table>

<td style="border-style: none;">

<div style="border: solid 2px #666; width: 143px; height: 144px;">

<canvas width="140" height="140"></canvas>

</div></td>

<td style="border-style: none;">

<button onclick="clear_value()">Clear</button>

</td>

</table>

"""



javascript = """

<script type="text/Javascript">

    var pixels = [];

    for (var i = 0; i < 28*28; i++) pixels[i] = 0

    var click = 0;



    var canvas = document.querySelector("canvas");

    canvas.addEventListener("mousemove", function(e){

        if (e.buttons == 1) {

            click = 1;

            canvas.getContext("2d").fillStyle = "rgb(0,0,0)";

            canvas.getContext("2d").fillRect(e.offsetX, e.offsetY, 8, 8);

            x = Math.floor(e.offsetY * 0.2)

            y = Math.floor(e.offsetX * 0.2) + 1

            for (var dy = 0; dy < 2; dy++){

                for (var dx = 0; dx < 2; dx++){

                    if ((x + dx < 28) && (y + dy < 28)){

                        pixels[(y+dy)+(x+dx)*28] = 1

                    }

                }

            }

        } else {

            if (click == 1) set_value()

            click = 0;

        }

    });

    

    function set_value(){

        var result = ""

        for (var i = 0; i < 28*28; i++) result += pixels[i] + ","

        var kernel = IPython.notebook.kernel;

        kernel.execute("image = [" + result + "]");

    }

    

    function clear_value(){

        canvas.getContext("2d").fillStyle = "rgb(255,255,255)";

        canvas.getContext("2d").fillRect(0, 0, 140, 140);

        for (var i = 0; i < 28*28; i++) pixels[i] = 0

    }

</script>

"""
from IPython.display import HTML
HTML(input_form + javascript)
# Out:
# <table>
#
# <td style="border-style: none;">
#
# <div style="border: solid 2px #666; width: 143px; height: 144px;">
#
# <canvas width="140" height="140"></canvas>
#
# </div></td>
#
# <td style="border-style: none;">
#
# <button onclick="clear_value()">Clear</button>
#
# </td>
#
# </table>
#
#
#
# <script type="text/Javascript">
#
#     var pixels = [];
#
#     for (var i = 0; i < 28*28; i++) pixels[i] = 0
#
#     var click = 0;
#
#
#
#     var canvas = document.querySelector("canvas");
#
#     canvas.addEventListener("mousemove", function(e){
#
#         if (e.buttons == 1) {
#
#             click = 1;
#
#             canvas.getContext("2d").fillStyle = "rgb(0,0,0)";
#
#             canvas.getContext("2d").fillRect(e.offsetX, e.offsetY, 8, 8);
#
#             x = Math.floor(e.offsetY * 0.2)
#
#             y = Math.floor(e.offsetX * 0.2) + 1
#
#             for (var dy = 0; dy < 2; dy++){
#
#                 for (var dx = 0; dx < 2; dx++){
#
#                     if ((x + dx < 28) && (y + dy < 28)){
#
#                         pixels[(y+dy)+(x+dx)*28] = 1
#
#                     }
#
#                 }
#
#             }
#
#         } else {
#
#             if (click == 1) set_value()
#
#             click = 0;
#
#         }
#
#     });
#
#
#
#     function set_value(){
#
#         var result = ""
#
#         for (var i = 0; i < 28*28; i++) result += pixels[i] + ","
#
#         var kernel = IPython.notebook.kernel;
#
#         kernel.execute("image = [" + result + "]");
#
#     }
#
#
#
#     function clear_value(){
#
#         canvas.getContext("2d").fillStyle = "rgb(255,255,255)";
#
#         canvas.getContext("2d").fillRect(0, 0, 140, 140);
#
#         for (var i = 0; i < 28*28; i++) pixels[i] = 0
#
#     }
#
# </script>

# %%
# from numpy import load
# data = load('fork.npy')
# data = list(np.reshape(data, (-1, 784)))
# data = np.array(data).astype(np.float32)
import operator
for i in range(len(image)):
    image[i] = image[i] * 255
p_val = sess.run(p, feed_dict={x:[image], keep_prob:1.0})
answer = ['사과','바나나','야구 방망이','새','구름','커피 잔','물고기','포크','막대 사탕','버섯']

a = sum(p_val.tolist(),[])
index, value = max(enumerate(a), key=operator.itemgetter(1))
print(index, value)
print(answer[index])
fig = plt.figure(figsize=(4,2))

pred = p_val[0]

subplot = fig.add_subplot(1,1,1)

subplot.set_xticks(range(10))

subplot.set_xlim(-0.5,9.5)

subplot.set_ylim(0,1)

subplot.bar(range(10), pred, align='center')

plt.show()
# Out:
# 6 0.9961632490158081
# 물고기
